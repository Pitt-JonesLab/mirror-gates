# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(4)
qc.cx(0, 1)
qc.cx(2, 1)
qc.swap(1, 2)
qc.cx(3, 2)
print(qc)
# Out:
#
# q_0: ──■───────────────
#      ┌─┴─┐┌───┐
# q_1: ┤ X ├┤ X ├─X──────
#      └───┘└─┬─┘ │ ┌───┐
# q_2: ───────■───X─┤ X ├
#                   └─┬─┘
# q_3: ───────────────■──

# %%
img = qc.draw("latex", filename="base5.pdf")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=216x119>
