# %%
from qiskit.transpiler import CouplingMap

t = CouplingMap.from_heavy_hex(3)
t.size()
# Out:
# 19

# %%
from transpile_benchy.library import CircuitLibrary

lib = CircuitLibrary(circuit_list=[])
for interface in lib.interfaces:
    print(interface.__class__.__name__)
    print(interface.circuits)
# Out:
# QASMBench
# ['wstate_n118', 'multiplier_n400', 'cc_n64', 'qft_n320', 'qft_n160', 'dnn_n51', 'qft_n63', 'ghz_state_n255', 'swap_test_n361', 'ising_n420', 'qugan_n111', 'knn_341', 'qugan_n395', 'cc_n301', 'qugan_n71', 'bv_n280', 'ghz_n127', 'knn_n31', 'bv_n140', 'bv_n70', 'qugan_n39', 'ghz_n78', 'ising_n66', 'multiplier_n350', 'knn_n67', 'square_root_n60', 'ising_n98', 'cat_n35', 'multiplier_n75', 'square_root_n45', 'cc_n32', 'adder_n433', 'cat_n260', 'adder_n28', 'cc_n151', 'bv_n30', 'cat_n65', 'wstate_n76', 'swap_test_n83', 'knn_129', 'adder_n64', 'ghz_n40', 'cat_n130', 'swap_test_n115', 'adder_n118', 'wstate_n380', 'multiplier_n45', 'ising_n34', 'qft_n29', 'swap_test_n41', 'dnn_n33', 'wstate_n36', 'qec_en_n5', 'qaoa_n3', 'grover_n2', 'toffoli_n3', 'hs4_n4', 'variational_n4', 'error_correctiond3_n5', 'deutsch_n2', 'ipea_n2', 'hhl_n7', 'bell_n4', 'quantumwalks_n2', 'wstate_n3', 'shor_n5', 'ising_n10', 'dnn_n2', 'basis_test_n4', 'basis_trotter_n4', 'basis_change_n3', 'cat_state_n4', 'bb84_n8', 'teleportation_n3', 'qrng_n4', 'fredkin_n3', 'qec_sm_n5', 'adder_n10', 'qaoa_n6', 'hhl_n10', 'qpe_n9', 'dnn_n8', 'adder_n4', 'linearsolver_n3', 'qft_n4', 'lpn_n5', 'pea_n5', 'iswap_n2', 'simon_n6', 'multiplier_n15', 'bigadder_n18', 'bv_n14', 'dnn_n16', 'square_root_n18', 'qram_n20', 'swap_test_n25', 'qf21_n15', 'sat_n11', 'knn_n25', 'cat_state_n22', 'qec9xz_n17', 'multiply_n13', 'seca_n11', 'qft_n18', 'ghz_state_n23', 'bv_n19']
# RedQueen
# ['ft_n1', 'hs', 'ipe', 'dj_nbalanced', 'bv', 'dj_nconstant', 'grover', 'bv_nmcm', 'qpe', 'ft_n2', 'quantum_nteleportation', 'wim_n266', 'cm42a_n207', 'alu-v2_n32', 'radd_n250', 'sym9_n193', 'sym9_n146', '4mod5-bdd_n287', '4gt11_n82', 'mini_alu_n305', 'one-two-three-v1_n99', 'inc_n237', 'one-two-three-v0_n97', '4gt13_n92', 'decod24-v3_n45', 'alu-v3_n35', '4mod5-v1_n23', 'sf_n274', 'decod24-v0_n38', 'ising_model_n13', 'ham7_n104', '4gt12-v0_n87', '4mod5-v1_n24', 'squar5_n261', 'sym9_n148', 'rd73_n252', 'urf1_n149', 'alu-bdd_n288', 'rd84_n253', 'alu-v2_n31', 'rd53_n135', 'majority_n239', '4mod5-v1_n22', 'sao2_n257', 'decod24-v1_n41', 'sqn_n258', 'mini-alu_n167', '0410184_n169', 'dc2_n222', 'hwb9_n119', 'mod10_n171', 'life_n238', 'hwb4_n49', 'one-two-three-v3_n101', '4gt5_n75', 'urf6_n160', 'xor5_n254', 'hwb5_n53', 'hwb7_n59', 'alu-v1_n28', 'alu-v4_n36', 'sqrt8_n260', '4gt4-v0_n80', 'dist_n223', '4gt4-v1_n74', '4mod5-v0_n18', 'urf2_n277', 'mod5d1_n63', 'alu-v3_n34', 'cm82a_n208', 'graycode6_n47', 'root_n255', '3_17_n13', 'alu-v0_n26', 'alu-v2_n30', '4_49_n16', '4gt12-v1_n89', '4gt11_n84', '4gt11_n83', 'adr4_n197', 'rd32_n270', 'rd32-v0_n66', '4gt12-v0_n86', 'cycle10_2_n110', '4mod5-v0_n20', 'rd53_n131', 'alu-v4_n37', 'urf1_n278', 'mod10_n176', '4gt13_n90', 'urf5_n280', 'rd53_n311', 'cnt3-5_n180', 'decod24-bdd_n294', 'con1_n216', 'qft_n16', 'alu-v2_n33', 'rd73_n140', 'ex2_n227', '4mod7-v1_n96', '4mod5-v0_n19', '4gt4-v0_n72', 'rd53_n130', 'alu-v0_n27', 'urf3_n279', 'plus63mod4096_n163', 'ex1_n226', 'rd32-v1_n68', '4mod7-v0_n94', '4gt5_n77', 'urf4_n187', '4gt4-v0_n79', 'miller_n11', 'max46_n240', 'ising_model_n16', 'rd53_n251', 'cm85a_n209', 'plus63mod8192_n164', 'decod24-v2_n43', 'hwb8_n113', '4gt10-v1_n81', 'sym10_n262', 'mod8-10_n178', 'ham3_n102', 'rd53_n133', 'ex-1_n166', '9symml_n195', 'sf_n276', 'sym6_n145', '4gt4-v0_n73', '4gt4-v0_n78', 'clip_n206', 'f2_n232', 'cnt3-5_n179', 'ground_state_estimation_n10', 'mod5mils_n65', 'sys6-v0_n111', 'urf2_n152', 'C17_n204', 'square_root_n7', 'mod8-10_n177', 'alu-v1_n29', 'ham15_n107', 'pm1_n249', 'co14_n215', 'rd84_n142', 'aj-e11_n165', 'decod24-enable_n126', 'one-two-three-v2_n100', '4gt5_n76', 'ising_model_n10', 'dc1_n220', '4gt13-v1_n93', 'rd53_n138', 'hwb6_n56', 'mlp4_n245', '4gt12-v0_n88', '4gt13_n91', 'cm152a_n212', 'misex1_n241', 'urf5_n158', 'one-two-three-v0_n98', 'sym6_n316', 'qft_n10', 'urf3_n155', 'z4_n268', 'mod5adder_n127', 'mod5d2_n64', 'ex3_n229', '53QBT_400CYC_QSE_n6', '20QBT_500CYC_QSE_n8', '20QBT_600CYC_QSE_n9', '54QBT_200CYC_QSE_n4', '53QBT_300CYC_QSE_n2', '16QBT_600CYC_QSE_n3', '53QBT_600CYC_QSE_n6', '53QBT_200CYC_QSE_n1', '16QBT_900CYC_QSE_n5', '20QBT_700CYC_QSE_n2', '20QBT_500CYC_QSE_n6', '16QBT_200CYC_QSE_n9', '20QBT_700CYC_QSE_n4', '54QBT_500CYC_QSE_n7', '16QBT_300CYC_QSE_n7', '20QBT_100CYC_QSE_n4', '16QBT_200CYC_QSE_n7', '53QBT_200CYC_QSE_n3', '53QBT_600CYC_QSE_n8', '16QBT_900CYC_QSE_n8', '16QBT_100CYC_QSE_n5', '20QBT_900CYC_QSE_n3', '53QBT_700CYC_QSE_n0', '53QBT_700CYC_QSE_n7', '53QBT_700CYC_QSE_n4', '20QBT_300CYC_QSE_n3', '20QBT_300CYC_QSE_n8', '53QBT_600CYC_QSE_n0', '20QBT_600CYC_QSE_n7', '20QBT_500CYC_QSE_n1', '54QBT_500CYC_QSE_n1', '16QBT_900CYC_QSE_n9', '16QBT_900CYC_QSE_n0', '53QBT_500CYC_QSE_n6', '16QBT_800CYC_QSE_n1', '20QBT_600CYC_QSE_n1', '54QBT_300CYC_QSE_n3', '54QBT_300CYC_QSE_n6', '16QBT_300CYC_QSE_n3', '16QBT_400CYC_QSE_n4', '53QBT_100CYC_QSE_n3', '54QBT_700CYC_QSE_n2', '53QBT_600CYC_QSE_n1', '54QBT_100CYC_QSE_n9', '16QBT_700CYC_QSE_n3', '53QBT_300CYC_QSE_n5', '20QBT_700CYC_QSE_n9', '53QBT_900CYC_QSE_n8', '16QBT_400CYC_QSE_n3', '16QBT_800CYC_QSE_n4', '53QBT_700CYC_QSE_n5', '54QBT_600CYC_QSE_n7', '16QBT_700CYC_QSE_n2', '20QBT_500CYC_QSE_n2', '16QBT_500CYC_QSE_n6', '54QBT_300CYC_QSE_n2', '54QBT_700CYC_QSE_n3', '54QBT_200CYC_QSE_n2', '16QBT_200CYC_QSE_n8', '53QBT_900CYC_QSE_n0', '53QBT_900CYC_QSE_n5', '16QBT_600CYC_QSE_n8', '54QBT_800CYC_QSE_n6', '16QBT_100CYC_QSE_n3', '16QBT_400CYC_QSE_n2', '53QBT_500CYC_QSE_n5', '53QBT_700CYC_QSE_n1', '54QBT_400CYC_ ...
# MQTBench
# ['ae', 'dj', 'grover-noancilla', 'grover-v-chain', 'ghz', 'graphstate', 'portfolioqaoa', 'portfoliovqe', 'qaoa', 'qft', 'qftentangled', 'qnn', 'qpeexact', 'qpeinexact', 'qwalk-noancilla', 'qwalk-v-chain', 'random', 'realamprandom', 'su2random', 'twolocalrandom', 'vqe', 'wstate', 'pricingcall', 'pricingput', 'routing', 'tsp']
# BQSKitInterface
# ['grover_n5', 'hub_n18', 'qft_n64', 'qft_n5', 'shor_n26', 'tfim_n64', 'mul_n60', 'tfxy_n64', 'adder_n63', 'qaoa_n12']
# QiskitCircuitInterface
# ['vqe_full', 'vqe_linear', 'qv', 'qft', 'qaoa', 'adder', 'mul', 'ghz', 'hlf', 'grover']

# %%
lib = CircuitLibrary.from_txt("medium_circuits.txt")
